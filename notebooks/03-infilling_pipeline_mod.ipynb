# %%
#!/usr/bin/env python
# coding: utf-8

# In[117]:

# DF-Net Imports
from collections import defaultdict
import cv2
from itertools import islice
from multiprocessing.pool import ThreadPool as Pool
from pathlib import Path
import torch.nn.functional as F
import tqdm

# Imports
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from PIL import Image
from pytorch_metric_learning import losses, samplers
from random import randint
import shutil
from skimage import io, transform
import time
import torch
from torch.autograd import Variable
import torch.nn as nn
from torch.utils.data.sampler import Sampler
from torchvision import datasets, models, transforms
from torchvision.utils import save_image

# In[118]:


from sklearn.manifold import TSNE


def map_features(outputs, labels, out_file):
    # create array of column for each feature output
    feat_cols = ['feature' + str(i) for i in range(outputs.shape[1])]
    # make dataframe of outputs -> labels
    df = pd.DataFrame(outputs, columns=feat_cols)
    df['y'] = labels
    df['labels'] = df['y'].apply(lambda i: str(i))
    # clear outputs and labels
    outputs, labels = None, None
    # creates an array of random indices from size of outputs
    np.random.seed(42)
    rndperm = np.random.permutation(df.shape[0])
    num_examples = 3000
    df_subset = df.loc[rndperm[:num_examples], :].copy()
    data_subset = df_subset[feat_cols].values
    tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=300)
    tsne_results = tsne.fit_transform(data_subset)
    df_subset['tsne-2d-one'] = tsne_results[:, 0]
    df_subset['tsne-2d-two'] = tsne_results[:, 1]
    plt.figure(figsize=(16, 10))
    plt.scatter(
        x=df_subset["tsne-2d-one"],
        y=df_subset["tsne-2d-two"],
        c=df_subset["y"],
        s=3
    )
    plt.savefig(out_file, bbox_inches='tight', pad_inches=0)
    plt.close()



# Configurations
# Device
device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")

# Num epochs
num_epochs = 200

# Model
model = models.resnet18()
# model = ClassifierSiLU()

# Optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=0.5, momentum=0.9)

# Batch size
batch_size = 20

# Data set
# train_path = '/lab/vislab/DATA/CUB/images/train/'
train_path = '/lab/vislab/DATA/just/infilling/mini/'

mask_path = './samples/places2/mask/'

# Loss function
criterion = losses.TripletMarginLoss(margin=0.05)
# criterion = torch.nn.CosineEmbeddingLoss()


# In[120]:


class RandomMask(object):
    """Add random occlusions to image.

    Args:
        mask: (Image.Image) - Image to use to occlude.
    """

    def __init__(self, mask):
        assert isinstance(mask, Image.Image)
        self.mask = mask

    def __call__(self, sample):
        self.mask = self.mask.resize((128, 128))
        theta = randint(0, 45)
        self.mask = self.mask.rotate(angle=theta)
        seed_x = randint(1, 10)
        seed_y = randint(1, 10)
        sample.paste(self.mask, (20 * seed_x, 20 * seed_y))

        return sample


# In[121]:


# Dataset

# mask = Image.open('./samples/places2/mask/mask_01.png')

transformations = transforms.Compose([
    transforms.Resize((256, 256)),
    #     RandomMask(mask),
    transforms.ToTensor(),
])

dataset = datasets.ImageFolder(train_path, transformations)

# plt.imshow(transforms.ToPILImage()(dataset[3][0]), interpolation="bicubic")

# train_set, test_set = torch.utils.data.random_split(dataset, [5000, 1033])
# train_set, test_set = torch.utils.data.random_split(dataset, [33, 6000])

### remove the split, for now at least ... ###

# train_sampler = torch.utils.data.RandomSampler(train_set)

# train_sampler = samplers.MPerClassSampler(dataset.targets, 2, len(dataset))  # maybe train set
train_sampler = samplers.MPerClassSampler(dataset.targets, 2, len(dataset))

train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                           sampler=train_sampler, num_workers=4, drop_last=True)


# In[122]:


# DF-Net Utils

def resize_like(x, target, mode='bilinear'):
    return F.interpolate(x, target.shape[-2:], mode=mode, align_corners=False)


def list2nparray(lst, dtype=None):
    """fast conversion from nested list to ndarray by pre-allocating space"""
    if isinstance(lst, np.ndarray):
        return lst
    assert isinstance(lst, (list, tuple)), 'bad type: {}'.format(type(lst))
    assert lst, 'attempt to convert empty list to np array'
    if isinstance(lst[0], np.ndarray):
        dim1 = lst[0].shape
        assert all(i.shape == dim1 for i in lst)
        if dtype is None:
            dtype = lst[0].dtype
            assert all(i.dtype == dtype for i in lst), 'bad dtype: {} {}'.format(dtype, set(i.dtype for i in lst))
    elif isinstance(lst[0], (int, float, complex, np.number)):
        return np.array(lst, dtype=dtype)
    else:
        dim1 = list2nparray(lst[0])
        if dtype is None:
            dtype = dim1.dtype
        dim1 = dim1.shape
    shape = [len(lst)] + list(dim1)
    rst = np.empty(shape, dtype=dtype)
    for idx, i in enumerate(lst):
        rst[idx] = i
    return rst


def get_img_list(path):
    return sorted(list(Path(path).glob('*.png'))) + sorted(list(Path(path).glob('*.jpg'))) + sorted(
        list(Path(path).glob('*.jpeg')))


def gen_miss(img, mask, output):
    imgs = get_img_list(img)
    masks = get_img_list(mask)
    print('Total images:', len(imgs), len(masks))

    out = Path(output)
    out.mkdir(parents=True, exist_ok=True)

    for i, (img, mask) in tqdm.tqdm(enumerate(zip(imgs, masks))):
        path = out.joinpath('miss_%04d.png' % (i + 1))
        img = cv2.imread(str(img), cv2.IMREAD_COLOR)
        mask = cv2.imread(str(mask), cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, img.shape[:2][::-1])
        mask = mask[..., np.newaxis]
        miss = img * (mask > 127) + 255 * (mask <= 127)

        cv2.imwrite(str(path), miss)


def merge_imgs(dirs, output, row=1, gap=2, res=512):
    image_list = [get_img_list(path) for path in dirs]
    img_count = [len(image) for image in image_list]
    print('Total images:', img_count)  # should be batch size when we walk back into here ...
    assert min(img_count) > 0, 'Please check the path of empty folder.'

    output_dir = Path(output)
    output_dir.mkdir(parents=True, exist_ok=True)

    n_img = len(dirs)
    row = row
    column = (n_img - 1) // row + 1
    print('Row:', row)
    print('Column:', column)

    for i, unit in tqdm.tqdm(enumerate(zip(*image_list))):
        name = output_dir.joinpath('merge_%04d.png' % i)
        merge = np.ones([
            res * row + (row + 1) * gap, res * column + (column + 1) * gap, 3], np.uint8) * 255
        for j, img in enumerate(unit):
            r = j // column
            c = j - r * column
            img = cv2.imread(str(img), cv2.IMREAD_COLOR)
            if img.shape[:2] != (res, res):
                img = cv2.resize(img, (res, res))
            start_h, start_w = (r + 1) * gap + r * res, (c + 1) * gap + c * res
            merge[start_h: start_h + res, start_w: start_w + res] = img
        cv2.imwrite(str(name), merge)


# In[123]:


# DF-Net Model

def get_norm(name, out_channels):
    if name == 'batch':
        norm = nn.BatchNorm2d(out_channels)
    elif name == 'instance':
        norm = nn.InstanceNorm2d(out_channels)
    else:
        norm = None
    return norm


def get_activation(name):
    if name == 'relu':
        activation = nn.ReLU()
    elif name == 'elu':
        activation == nn.ELU()
    elif name == 'leaky_relu':
        activation = nn.LeakyReLU(negative_slope=0.2)
    elif name == 'tanh':
        activation = nn.Tanh()
    elif name == 'sigmoid':
        activation = nn.Sigmoid()
    else:
        activation = None
    return activation


class Conv2dSame(nn.Module):

    def __init__(self, in_channels, out_channels, kernel_size, stride):
        super().__init__()

        padding = self.conv_same_pad(kernel_size, stride)
        if type(padding) is not tuple:
            self.conv = nn.Conv2d(
                in_channels, out_channels, kernel_size, stride, padding)
        else:
            self.conv = nn.Sequential(
                nn.ConstantPad2d(padding * 2, 0),
                nn.Conv2d(in_channels, out_channels, kernel_size, stride, 0)
            )

    def conv_same_pad(self, ksize, stride):
        if (ksize - stride) % 2 == 0:
            return (ksize - stride) // 2
        else:
            left = (ksize - stride) // 2
            right = left + 1
            return left, right

    def forward(self, x):
        return self.conv(x)


class ConvTranspose2dSame(nn.Module):

    def __init__(self, in_channels, out_channels, kernel_size, stride):
        super().__init__()

        padding, output_padding = self.deconv_same_pad(kernel_size, stride)
        self.trans_conv = nn.ConvTranspose2d(
            in_channels, out_channels, kernel_size, stride,
            padding, output_padding)

    def deconv_same_pad(self, ksize, stride):
        pad = (ksize - stride + 1) // 2
        outpad = 2 * pad + stride - ksize
        return pad, outpad

    def forward(self, x):
        return self.trans_conv(x)


class UpBlock(nn.Module):

    def __init__(self, mode='nearest', scale=2, channel=None, kernel_size=4):
        super().__init__()

        self.mode = mode
        if mode == 'deconv':
            self.up = ConvTranspose2dSame(
                channel, channel, kernel_size, stride=scale)
        else:
            def upsample(x):
                return F.interpolate(x, scale_factor=scale, mode=mode)

            self.up = upsample

    def forward(self, x):
        return self.up(x)


class EncodeBlock(nn.Module):

    def __init__(
            self, in_channels, out_channels, kernel_size, stride,
            normalization=None, activation=None):
        super().__init__()

        self.c_in = in_channels
        self.c_out = out_channels

        layers = []
        layers.append(
            Conv2dSame(self.c_in, self.c_out, kernel_size, stride))
        if normalization:
            layers.append(get_norm(normalization, self.c_out))
        if activation:
            layers.append(get_activation(activation))
        self.encode = nn.Sequential(*layers)

    def forward(self, x):
        return self.encode(x)


class DecodeBlock(nn.Module):

    def __init__(
            self, c_from_up, c_from_down, c_out, mode='nearest',
            kernel_size=4, scale=2, normalization='batch', activation='relu'):
        super().__init__()

        self.c_from_up = c_from_up
        self.c_from_down = c_from_down
        self.c_in = c_from_up + c_from_down
        self.c_out = c_out

        self.up = UpBlock(mode, scale, c_from_up, kernel_size=scale)

        layers = []
        layers.append(
            Conv2dSame(self.c_in, self.c_out, kernel_size, stride=1))
        if normalization:
            layers.append(get_norm(normalization, self.c_out))
        if activation:
            layers.append(get_activation(activation))
        self.decode = nn.Sequential(*layers)

    def forward(self, x, concat=None):
        out = self.up(x)
        if self.c_from_down > 0:
            out = torch.cat([out, concat], dim=1)
        out = self.decode(out)
        return out


class BlendBlock(nn.Module):

    def __init__(
            self, c_in, c_out, ksize_mid=3, norm='batch', act='leaky_relu'):
        super().__init__()
        c_mid = max(c_in // 2, 32)
        self.blend = nn.Sequential(
            Conv2dSame(c_in, c_mid, 1, 1),
            get_norm(norm, c_mid),
            get_activation(act),
            Conv2dSame(c_mid, c_out, ksize_mid, 1),
            get_norm(norm, c_out),
            get_activation(act),
            Conv2dSame(c_out, c_out, 1, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.blend(x)


class FusionBlock(nn.Module):
    def __init__(self, c_feat, c_alpha=1):
        super().__init__()
        c_img = 3
        self.map2img = nn.Sequential(
            Conv2dSame(c_feat, c_img, 1, 1),
            nn.Sigmoid())
        self.blend = BlendBlock(c_img * 2, c_alpha)

    def forward(self, img_miss, feat_de):
        img_miss = resize_like(img_miss, feat_de)
        raw = self.map2img(feat_de)
        alpha = self.blend(torch.cat([img_miss, raw], dim=1))
        result = alpha * raw + (1 - alpha) * img_miss
        return result, alpha, raw


class DFNet(nn.Module):
    def __init__(
            self, c_img=3, c_mask=1, c_alpha=3,
            mode='nearest', norm='batch', act_en='relu', act_de='leaky_relu',
            en_ksize=[7, 5, 5, 3, 3, 3, 3, 3], de_ksize=[3] * 8,
            blend_layers=[0, 1, 2, 3, 4, 5]):
        super().__init__()

        c_init = c_img + c_mask

        self.n_en = len(en_ksize)
        self.n_de = len(de_ksize)
        assert self.n_en == self.n_de, (
            'The number layer of Encoder and Decoder must be equal.')
        assert self.n_en >= 1, (
            'The number layer of Encoder and Decoder must be greater than 1.')

        assert 0 in blend_layers, 'Layer 0 must be blended.'

        self.en = []
        c_in = c_init
        self.en.append(
            EncodeBlock(c_in, 64, en_ksize[0], 2, None, None))
        for k_en in en_ksize[1:]:
            c_in = self.en[-1].c_out
            c_out = min(c_in * 2, 512)
            self.en.append(EncodeBlock(
                c_in, c_out, k_en, stride=2,
                normalization=norm, activation=act_en))

        # register parameters
        for i, en in enumerate(self.en):
            self.__setattr__('en_{}'.format(i), en)

        self.de = []
        self.fuse = []
        for i, k_de in enumerate(de_ksize):

            c_from_up = self.en[-1].c_out if i == 0 else self.de[-1].c_out
            c_out = c_from_down = self.en[-i - 1].c_in
            layer_idx = self.n_de - i - 1

            self.de.append(DecodeBlock(
                c_from_up, c_from_down, c_out, mode, k_de, scale=2,
                normalization=norm, activation=act_de))
            if layer_idx in blend_layers:
                self.fuse.append(FusionBlock(c_out, c_alpha))
            else:
                self.fuse.append(None)

        # register parameters
        for i, de in enumerate(self.de[::-1]):
            self.__setattr__('de_{}'.format(i), de)
        for i, fuse in enumerate(self.fuse[::-1]):
            if fuse:
                self.__setattr__('fuse_{}'.format(i), fuse)

    def forward(self, img_miss, mask):

        out = torch.cat([img_miss, mask], dim=1)

        out_en = [out]
        for encode in self.en:
            out = encode(out)
            out_en.append(out)

        results = []
        alphas = []
        raws = []
        for i, (decode, fuse) in enumerate(zip(self.de, self.fuse)):
            out = decode(out, out_en[-i - 2])
            if fuse:
                result, alpha, raw = fuse(img_miss, out)
                results.append(result)
                alphas.append(alpha)
                raws.append(raw)

        return results[::-1], alphas[::-1], raws[::-1]


# In[124]:


# Inpainter

class Inpainter:

    def __init__(self, model_path, input_size, batch_size):
        self.model_path = model_path
        self._input_size = input_size
        self.batch_size = batch_size
        self.init_model(model_path)

    @property
    def input_size(self):
        if self._input_size > 0:
            return (self._input_size, self._input_size)
        elif 'celeba' in self.model_path:
            return (256, 256)
        else:
            return (256, 256)

    def init_model(self, path):
        if torch.cuda.is_available():
            self.device = torch.device('cuda')
            print('Using gpu.')
        else:
            self.device = torch.device('cpu')
            print('Using cpu.')

        self.model = DFNet().to(self.device)
        checkpoint = torch.load(path, map_location=self.device)
        self.model.load_state_dict(checkpoint)
        self.model.eval()

        print('Model %s loaded.' % path)

    def get_name(self, path):
        return '.'.join(path.name.split('.')[:-1])

    def results_path(self, output, img_path, mask_path, prefix='result'):
        img_name = self.get_name(img_path)
        mask_name = self.get_name(mask_path)
        return {
            'result_path': self.sub_dir('result').joinpath(
                'result-{}-{}.png'.format(img_name, mask_name)),
            'raw_path': self.sub_dir('raw').joinpath(
                'raw-{}-{}.png'.format(img_name, mask_name)),
            'alpha_path': self.sub_dir('alpha').joinpath(
                'alpha-{}-{}.png'.format(img_name, mask_name))
        }

    def inpaint_instance(self, img, mask):
        """Assume color image with 3 dimension. CWH"""
        img = img.view(1, *img.shape)
        mask = mask.view(1, 1, *mask.shape)
        return self.inpaint_batch(img, mask).squeeze()

    def inpaint_batch(self, imgs, masks):
        """Assume color channel is BGR and input is NWHC np.uint8."""
        imgs = np.transpose(imgs, [0, 3, 1, 2])
        masks = np.transpose(masks, [0, 3, 1, 2])

        imgs = torch.from_numpy(imgs).to(self.device)
        masks = torch.from_numpy(masks).to(self.device)
        imgs = imgs.float().div(255)
        masks = masks.float().div(255)
        imgs_miss = imgs * masks
        results = self.model(imgs_miss, masks)
        if type(results) is list:
            results = results[0]
        results = results.mul(255).byte().data.cpu().numpy()
        results = np.transpose(results, [0, 2, 3, 1])
        return results

    def _process_file(self, output, img_path, mask_path):
        item = {
            'img_path': img_path,
            'mask_path': mask_path,
        }
        item.update(self.results_path(output, img_path, mask_path))
        self.path_pair.append(item)

    def process_single_file(self, output, img_path, mask_path):
        self.path_pair = []
        self._process_file(output, img_path, mask_path)

    def process_dir(self, output, img_dir, mask_dir):
        img_dir = Path(img_dir)
        mask_dir = Path(mask_dir)
        imgs_path = sorted(
            list(img_dir.glob('*.jpg')) + list(img_dir.glob('*.png')))
        masks_path = sorted(
            list(mask_dir.glob('*.jpg')) + list(mask_dir.glob('*.png')))

        n_img = len(imgs_path)
        n_mask = len(masks_path)
        n_pair = min(n_img, n_mask)

        self.path_pair = []
        for i in range(n_pair):
            img_path = imgs_path[i % n_img]
            mask_path = masks_path[i % n_mask]
            self._process_file(output, img_path, mask_path)

    def get_process(self, input_size):
        def process(pair):
            img = cv2.imread(str(pair['img_path']), cv2.IMREAD_COLOR)
            mask = cv2.imread(str(pair['mask_path']), cv2.IMREAD_GRAYSCALE)
            if input_size:
                #                 img = img[0:256, 0:256]
                #                 mask = mask[0:64, 0:64] ## ALSO HERE
                img = cv2.resize(img, input_size)
                mask = cv2.resize(mask, input_size)
            img = np.ascontiguousarray(img.transpose(2, 0, 1)).astype(np.uint8)
            mask = np.ascontiguousarray(
                np.expand_dims(mask, 0)).astype(np.uint8)

            pair['img'] = img
            pair['mask'] = mask
            return pair

        return process

    def _file_batch(self):
        pool = Pool()  # should be os.cpu_count() ...

        n_pair = len(self.path_pair)
        n_batch = (n_pair - 1) // self.batch_size + 1

        ##        n_batch = 4

        for i in tqdm.trange(n_batch, leave=False):
            _buffer = defaultdict(list)
            print(_buffer)
            start = i * self.batch_size
            stop = start + self.batch_size
            process = self.get_process(self.input_size)
            batch = pool.imap_unordered(
                process, islice(self.path_pair, start, stop))
            # so we aren't going through here, EDIT now we are

            for instance in batch:
                for k, v in instance.items():
                    _buffer[k].append(v)
            yield _buffer

        pool.close()
        pool.join()

    def batch_generator(self):
        generator = self._file_batch

        for _buffer in generator():
            for key in _buffer:

                if key in ['img', 'mask']:
                    _buffer[key] = list2nparray(_buffer[key])
            yield _buffer

    def to_numpy(self, tensor):
        tensor = tensor.mul(255).byte().data.cpu().numpy()
        tensor = np.transpose(tensor, [0, 2, 3, 1])
        return tensor

    def process_batch(self, batch, output, results):
        imgs = torch.from_numpy(batch['img']).to(self.device)
        masks = torch.from_numpy(batch['mask']).to(self.device)
        imgs = imgs.float().div(255)
        masks = masks.float().div(255)
        imgs_miss = imgs * masks

        result, alpha, raw = self.model(imgs_miss, masks)
        result, alpha, raw = result[0], alpha[0], raw[0]
        result = imgs * masks + result * (1 - masks)

        result = self.to_numpy(result)

        #         results.append(result)
        results = np.append(results, result, axis=0)

        alpha = self.to_numpy(alpha)
        raw = self.to_numpy(raw)

        for i in range(result.shape[0]):
            cv2.imwrite(str(batch['result_path'][i]), result[i])
            cv2.imwrite(str(batch['raw_path'][i]), raw[i])
            cv2.imwrite(str(batch['alpha_path'][i]), alpha[i])

    @property
    def root(self):
        return Path(self.output)

    def sub_dir(self, sub):
        return self.root.joinpath(sub)

    def prepare_folders(self, folders):
        for folder in folders:
            Path(folder).mkdir(parents=True, exist_ok=True)

    def inpaint(self, output, img, mask, merge_result=False):

        self.output = output
        self.prepare_folders([
            self.sub_dir('result'), self.sub_dir('alpha'),
            self.sub_dir('raw')])

        if os.path.isfile(img) and os.path.isfile(mask):
            if img.endswith(('.png', '.jpg', '.jpeg')):
                self.process_single_file(output, img, mask)
                _type = 'file'
            else:
                raise NotImplementedError()
        elif os.path.isdir(img) and os.path.isdir(mask):
            self.process_dir(output, img, mask)
            _type = 'dir'
        else:
            print('Img: ', img)
            print('Mask: ', mask)
            raise NotImplementedError(
                'img and mask should be both file or directory.')

        print('# Inpainting...')
        print('Input size:', self.input_size)
        results = np.empty((32, 256, 256, 3),
                           int)  # it's just following this dimension? # are we getting the error here?
        #         results = []
        for batch in self.batch_generator():
            self.process_batch(batch, output, results)
        print('Inpainting finished.')
        ## so results should contain everything now

        if merge_result and _type == 'dir':
            miss = self.sub_dir('miss')
            merge = self.sub_dir('merge')

            print('# Preparing input images...')
            gen_miss(img, mask, miss)  # dfnet util fn
            print('# Merging...')
            merge_imgs([
                miss, self.sub_dir('raw'), self.sub_dir('alpha'),
                self.sub_dir('result'), img], merge, res=self.input_size[0])
            print('Merging finished.')

        results = np.transpose(results, [0, 3, 1, 2])

        return results


# In[125]:


# Main Trainer
def train_model():
    """Generic function to train model"""

    start_time = datetime.now()
    correct = 0
    incorrect = 0
    num_batches = 1
    loss_values = []
    train_values = []

    # DF-Net Tester Instantiate
    pretrained_model_path = './model/model_places2.pth'
    inpainter = Inpainter(pretrained_model_path, 256, 8)  # was 8, should it be 1 or 32 or 128?

    # Epochs
    for epoch in range(num_epochs):
        print("epoch num:", epoch)

        for phase in ['train', 'valid']:

            running_outputs = torch.FloatTensor().cpu()
            running_labels = torch.LongTensor().cpu()
            running_loss = 0.0

            if phase == 'train':
                model.train()
            else:
                model.eval()

            # Batches
            for batch_idx, (inputs, labels) in enumerate(train_loader):

                # img_path = './samples/places2/img/'
                # os.makedirs(img_path)
                #
                # for img_idx in range(batch_size - 1):
                #
                #     img = inputs[img_idx]  # or is it running out here
                #
                #     img_idx_name = ''
                #     # so that should be 0-9
                #     if img_idx < 10:
                #         img_idx_name = '0%d' % img_idx
                #     else:
                #         img_idx_name = '%d' % img_idx
                #
                #     save_image(img, './samples/places2/img/img_{}.png'.format(img_idx_name))
                #
                # inpainted_img_batch = inpainter.inpaint('output/places2/', img_path, mask_path, merge_result=True)
                # inpainted_img_batch = torch.from_numpy(inpainted_img_batch)
                #             print(type(inpainted_img_batch[0]))
                #             print(inpainted_img_batch[0])

                #             delete img_path
                # shutil.rmtree(img_path)

                optimizer.zero_grad()
                inputs, labels = inputs.to(device), labels.to(device)

                # inpainted_img_batch, labels = inpainted_img_batch.to(device, dtype=torch.float), labels.to(device)

                # output = model.forward(inpainted_img_batch)
                output = model(inputs)

                #             print("inpainted_img_batch.shape",inpainted_img_batch.shape)
                #             print("labels.shape",labels.shape)

                loss = criterion(output, labels)
                # loss = Variable(loss, requires_grad=True)

                if phase == 'train':
                    loss.backward()
                    optimizer.step()

                if phase == 'valid':
                    running_outputs = torch.cat((running_outputs, output.cpu().detach()), 0)
                    running_labels = torch.cat((running_labels, labels.cpu().detach()), 0)

                running_loss += loss.item()
                num_batches += 1

            if phase == 'valid':
                # Accuracy
                for idx, emb in enumerate(running_outputs):
                    pairwise = torch.nn.PairwiseDistance(p=2).to(device)
                    dist = pairwise(emb, running_outputs)
                    closest = torch.topk(dist, 2, largest=False).indices[1]
                    ## this is only seeing about 10% accuracy
                    if running_labels[idx] == running_labels[closest]:
                        correct += 1
                    else:
                        incorrect += 1

                print(running_loss / num_batches)
                print("Correct", correct)
                print("Incorrect", incorrect)
                if correct + incorrect != 0:
                    accuracy = correct / (correct + incorrect)
                    train_values.append(accuracy)
                else:
                    accuracy = "this is weird AF "
                print("Accuracy: ", accuracy)

                # t-SNE
                # map_features(running_outputs, running_labels, "outfile")
                # Loss Plot
                loss_values.append(running_loss / num_batches)

            time_elapsed = datetime.now() - start_time
            print('Time elapsed (hh:mm:ss.ms) {}'.format(time_elapsed))

    plt.plot(train_values)
    plt.title("Accuracy Plots")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.show()
    plt.plot(loss_values)
    plt.title("Loss Function")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.show()
    return model, running_loss


# In[127]:


# Run Script

model.to(device)

# perhaps parameterize the train model to take in our pre-processed data

trained_model, loss = train_model()

# In[ ]:


# RuntimeError: Expected 4-dimensional input for 4-dimensional weight 64 3 7 7,
# but got 5-dimensional input of size [4, 8, 256, 256, 3] instead
# so just reshape that np first. change torch channel placement


## inpainted_img_batch.shape torch.Size([8, 3, 256, 256])
## labels.shape torch.Size([32])

# # Debug cell
# train_sampler = torch.utils.data.RandomSampler(train_set)
# train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size,
#                                            sampler=train_sampler, num_workers=4)
#
# for batch_idx, (inputs, labels) in enumerate(train_loader):
#     print(batch_idx)
#     print(type(inputs))
#     # plot
#     #     plt.imshow(transforms.ToPILImage()(inputs[31]), interpolation="bicubic")
#     print(inputs.shape)
#
#     break
#
# # In[ ]:
#
#
# # Test Script
#
# print(type(trained_model))
# trained_model.test()
#
# print("Finished.")
#
#
# # In[22]:
#
#
# # Testing
# def test():
#     trained_model.eval()
#     test_running_outputs = torch.FloatTensor().cpu()
#     test_running_labels = torch.LongTensor().cpu()
#     test_running_loss = 0.0
#     correct = 0
#     incorrect = 0
#
#     test_sampler = torch.utils.data.RandomSampler(test_set)
#     test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size,
#                                               sampler=test_sampler, num_workers=4)
#
#     with torch.no_grad():
#         for data, labels in test_loader:
#             data, labels = data.to(device), labels.to(device)
#             output = trained_model(data)
#
#             test_running_outputs = torch.cat((test_running_outputs, output.cpu().detach()), 0)
#             test_running_labels = torch.cat((test_running_labels, labels.cpu().detach()), 0)
#
#             test_loss = criterion(output, labels)
#             test_running_loss += loss.item()
#
#         # Accuracy
#         for idx, emb in enumerate(running_outputs.to(device)):
#             pairwise = torch.nn.PairwiseDistance(p=2).to(device)
#             dist = pairwise(emb, running_outputs.to(device))
#             closest = torch.topk(dist, 2, largest=False).indices[1]
#             if running_labels[idx] == running_labels[closest]:
#                 correct += 1
#             else:
#                 incorrect += 1
#
#         map_features(test_running_outputs, test_running_labels, "test_outfile")
#         print("correct", correct)
#         print("incorrect", incorrect)
#
# # In[ ]:
#
#
# # # DF-Net Train Loop
# # def train_dfnet():
# #     """Generic function to train model"""
#
# #     print("Training model ...")
#
# #     start_time = datetime.now()
# #     loss_values = []
# #     num_batches = 0
#
# #     # Epochs
# #     for epoch in range(num_epochs):
# #         print("epoch num:", epoch)
# #         train_sampler = torch.utils.data.RandomSampler(train_set)
# #         train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size,
# #                                                sampler=train_sampler, num_workers=4)
#
# #         running_outputs = torch.FloatTensor().cpu()
# #         running_labels = torch.LongTensor().cpu()
# #         running_loss = 0.0
# #         dfnet_model.train()
#
# #         # Batches
# #         for batch_idx, (inputs, labels) in enumerate(train_loader):
#
# #             num_batches += 1
# #             optimizer.zero_grad()
#
# #             inputs, labels = inputs.to(device), labels.to(device)
# #             output = dfnet_model.forward(inputs)
#
# #             running_outputs = torch.cat((running_outputs, output.cpu().detach()), 0)
# #             running_labels = torch.cat((running_labels, labels.cpu().detach()), 0)
#
# #             loss = criterion(output, labels)
# #             loss = Variable(loss, requires_grad = True)
#
# #             loss.backward()
# #             optimizer.step()
#
# #             running_loss += loss.item()
#
# #         # Loss Plot
# #         loss_values.append(running_loss / num_batches)
#
# #         time_elapsed = datetime.now() - start_time
# #         print('Time elapsed (hh:mm:ss.ms) {}'.format(time_elapsed))
#
# #     plt.plot(loss_values)
# #     return dfnet_model, running_loss
#
#
# # In[ ]:
#
#
# # # DF-Net outputs
# # # TODO: implement this
# # # but how can we parameterize thi?
#
# # def inpaint():
# #     running_outputs = torch.FloatTensor().cpu()
# #     running_labels = torch.LongTensor().cpu()
# #     running_loss = 0.0
#
# #     dfnet_sampler = torch.utils.data.RandomSampler(test_set)
# #     dfnet_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size,
# #                                            sampler=dfnet_sampler, num_workers=4)
#
# #     with torch.no_grad():
# #         for data, labels in dfnet_loader:
# #             data, labels = data.to(device), labels.to(device)
# #             output = model(data)
#
# #             running_outputs = torch.cat((running_outputs, output.cpu().detach()), 0)
# #             running_labels = torch.cat((running_labels, labels.cpu().detach()), 0)
#
# #             loss = criterion(output, labels)
# #             running_loss += loss.item()
#
#
# #     print(type(output))
# #     print(output.shape)
# #     print(type(output[0][0]))
#
# #     return output
#
#
# # In[ ]:
#
#
# # # Train DF-Net
# # dfnet_model.to(device)
# # dfnet_model, loss = train_dfnet()
#
# # print(loss)
#
# Out:
# Using gpu.
# Model ./model/model_places2.pth loaded.
# epoch num: 0
# Time elapsed (hh:mm:ss.ms) 0:00:02.851744
# 0.024456004798412322
# Correct 87
# Incorrect 53
# Accuracy:  0.6214285714285714
# Time elapsed (hh:mm:ss.ms) 0:00:03.796158
# epoch num: 1
# Time elapsed (hh:mm:ss.ms) 0:00:04.605780
# 0.012120942745743126
# Correct 185
# Incorrect 95
# Accuracy:  0.6607142857142857
# Time elapsed (hh:mm:ss.ms) 0:00:05.517666
# epoch num: 2
# Time elapsed (hh:mm:ss.ms) 0:00:06.405063
# 0.010821374263181242
# Correct 278
# Incorrect 142
# Accuracy:  0.6619047619047619
# Time elapsed (hh:mm:ss.ms) 0:00:07.273277
# epoch num: 3
# Time elapsed (hh:mm:ss.ms) 0:00:08.136359
# 0.007513499769725297
# Correct 364
# Incorrect 196
# Accuracy:  0.65
# Time elapsed (hh:mm:ss.ms) 0:00:09.081947
# epoch num: 4
# Time elapsed (hh:mm:ss.ms) 0:00:09.919362
# 0.00640853441936869
# Correct 448
# Incorrect 252
# Accuracy:  0.64
# Time elapsed (hh:mm:ss.ms) 0:00:10.776166
# epoch num: 5
# Time elapsed (hh:mm:ss.ms) 0:00:11.557729
# 0.00593962608014836
# Correct 538
# Incorrect 302
# Accuracy:  0.6404761904761904
# Time elapsed (hh:mm:ss.ms) 0:00:12.474947
# epoch num: 6
# Time elapsed (hh:mm:ss.ms) 0:00:13.289682
# 0.004793532945290961
# Correct 622
# Incorrect 358
# Accuracy:  0.6346938775510204
# Time elapsed (hh:mm:ss.ms) 0:00:14.152428
# epoch num: 7
# Time elapsed (hh:mm:ss.ms) 0:00:14.951656
# 0.004052718590318629
# Correct 710
# Incorrect 410
# Accuracy:  0.6339285714285714
# Time elapsed (hh:mm:ss.ms) 0:00:15.815220
# epoch num: 8
# Time elapsed (hh:mm:ss.ms) 0:00:16.590711
# 0.004147871038106482
# Correct 789
# Incorrect 471
# Accuracy:  0.6261904761904762
# Time elapsed (hh:mm:ss.ms) 0:00:17.476804
# epoch num: 9
# Time elapsed (hh:mm:ss.ms) 0:00:18.255387
# 0.0030900886718263016
# Correct 872
# Incorrect 528
# Accuracy:  0.6228571428571429
# Time elapsed (hh:mm:ss.ms) 0:00:19.087496
# epoch num: 10
# Time elapsed (hh:mm:ss.ms) 0:00:19.890126
# 0.002863373967909044
# Correct 969
# Incorrect 571
# Accuracy:  0.6292207792207792
# Time elapsed (hh:mm:ss.ms) 0:00:20.737698
# epoch num: 11
# Time elapsed (hh:mm:ss.ms) 0:00:21.504281
# 0.002486444458629958
# Correct 1053
# Incorrect 627
# Accuracy:  0.6267857142857143
# Time elapsed (hh:mm:ss.ms) 0:00:22.336552
# epoch num: 12
# Time elapsed (hh:mm:ss.ms) 0:00:23.268028
# 0.0021733069191864933
# Correct 1155
# Incorrect 665
# Accuracy:  0.6346153846153846
# Time elapsed (hh:mm:ss.ms) 0:00:24.141523
# epoch num: 13
# Time elapsed (hh:mm:ss.ms) 0:00:24.905756
# 0.002105554745433294
# Correct 1239
# Incorrect 721
# Accuracy:  0.6321428571428571
# Time elapsed (hh:mm:ss.ms) 0:00:25.731627
# epoch num: 14
# Time elapsed (hh:mm:ss.ms) 0:00:26.563737
# 0.002076687353058449
# Correct 1330
# Incorrect 770
# Accuracy:  0.6333333333333333
# Time elapsed (hh:mm:ss.ms) 0:00:27.385657
# epoch num: 15
# Time elapsed (hh:mm:ss.ms) 0:00:28.190275
# 0.0018726697895261977
# Correct 1419
# Incorrect 821
# Accuracy:  0.6334821428571429
# Time elapsed (hh:mm:ss.ms) 0:00:29.057747
# epoch num: 16
# Time elapsed (hh:mm:ss.ms) 0:00:29.859200
# 0.0015007952797113603
# Correct 1512
# Incorrect 868
# Accuracy:  0.6352941176470588
# Time elapsed (hh:mm:ss.ms) 0:00:30.733123
# epoch num: 17
# Time elapsed (hh:mm:ss.ms) 0:00:31.546594
# 0.0015129517219047773
# Correct 1607
# Incorrect 913
# Accuracy:  0.6376984126984127
# Time elapsed (hh:mm:ss.ms) 0:00:32.454123
# epoch num: 18
# Time elapsed (hh:mm:ss.ms) 0:00:33.262802
# 0.0014335022269563282
# Correct 1700
# Incorrect 960
# Accuracy:  0.6390977443609023
# Time elapsed (hh:mm:ss.ms) 0:00:34.163157
# epoch num: 19
# Time elapsed (hh:mm:ss.ms) 0:00:34.955271
# 0.0014402373856284864
# Correct 1803
# Incorrect 997
# Accuracy:  0.6439285714285714
# Time elapsed (hh:mm:ss.ms) 0:00:35.802819
# epoch num: 20
# Time elapsed (hh:mm:ss.ms) 0:00:36.671363
# 0.0014508499558699333
# Correct 1897
# Incorrect 1043
# Accuracy:  0.6452380952380953
# Time elapsed (hh:mm:ss.ms) 0:00:37.597871
# epoch num: 21
# Time elapsed (hh:mm:ss.ms) 0:00:38.549983
# 0.0013341360445161467
# Correct 1990
# Incorrect 1090
# Accuracy:  0.6461038961038961
# Time elapsed (hh:mm:ss.ms) 0:00:39.424120
# epoch num: 22
# Time elapsed (hh:mm:ss.ms) 0:00:40.208080
# 0.0011654135312642844
# Correct 2077
# Incorrect 1143
# Accuracy:  0.6450310559006212
# Time elapsed (hh:mm:ss.ms) 0:00:41.030558
# epoch num: 23
# Time elapsed (hh:mm:ss.ms) 0:00:41.804716
# 0.0013051205908863057
# Correct 2165
# Incorrect 1195
# Accuracy:  0.6443452380952381
# Time elapsed (hh:mm:ss.ms) 0:00:42.623817
# epoch num: 24
# Time elapsed (hh:mm:ss.ms) 0:00:43.486932
# 0.0010321896915931647
# Correct 2266
# Incorrect 1234
# Accuracy:  0.6474285714285715
# Time elapsed (hh:mm:ss.ms) 0:00:44.383232
# epoch num: 25
# Time elapsed (hh:mm:ss.ms) 0:00:45.326031
# 0.001169508501683196
# Correct 2371
# Incorrect 1269
# Accuracy:  0.6513736263736264
# Time elapsed (hh:mm:ss.ms) 0:00:46.157780
# epoch num: 26
# Time elapsed (hh:mm:ss.ms) 0:00:46.935857
# 0.0010429679030321518
# Correct 2475
# Incorrect 1305
# Accuracy:  0.6547619047619048
# Time elapsed (hh:mm:ss.ms) 0:00:47.723267
# epoch num: 27
# Time elapsed (hh:mm:ss.ms) 0:00:48.463108
# 0.0011311307378852641
# Correct 2558
# Incorrect 1362
# Accuracy:  0.6525510204081633
# Time elapsed (hh:mm:ss.ms) 0:00:49.327510
# epoch num: 28
# Time elapsed (hh:mm:ss.ms) 0:00:50.084292
# 0.0009216121066114533
# Correct 2659
# Incorrect 1401
# Accuracy:  0.6549261083743843
# Time elapsed (hh:mm:ss.ms) 0:00:50.920033
# epoch num: 29
# Time elapsed (hh:mm:ss.ms) 0:00:51.737752
# 0.0009366308920740232
# Correct 2759
# Incorrect 1441
# Accuracy:  0.6569047619047619
# Time elapsed (hh:mm:ss.ms) 0:00:52.590031
# epoch num: 30
# Time elapsed (hh:mm:ss.ms) 0:00:53.410258
# 0.0008670451312229551
# Correct 2863
# Incorrect 1477
# Accuracy:  0.6596774193548387
# Time elapsed (hh:mm:ss.ms) 0:00:54.238619
# epoch num: 31
# Time elapsed (hh:mm:ss.ms) 0:00:55.014479
# 0.0009020228428405218
# Correct 2964
# Incorrect 1516
# Accuracy:  0.6616071428571428
# Time elapsed (hh:mm:ss.ms) 0:00:55.885095
# epoch num: 32
# Time elapsed (hh:mm:ss.ms) 0:00:56.656915
# 0.0008814453386719747
# Correct 3069
# Incorrect 1551
# Accuracy:  0.6642857142857143
# Time elapsed (hh:mm:ss.ms) 0:00:57.493538
# epoch num: 33
# Time elapsed (hh:mm:ss.ms) 0:00:58.289834
# 0.000927367972003089
# Correct 3176
# Incorrect 1584
# Accuracy:  0.6672268907563025
# Time elapsed (hh:mm:ss.ms) 0:00:59.079857
# epoch num: 34
# Time elapsed (hh:mm:ss.ms) 0:00:59.845822
# 0.0007221213942147078
# Correct 3276
# Incorrect 1624
# Accuracy:  0.6685714285714286
# Time elapsed (hh:mm:ss.ms) 0:01:00.630651
# epoch num: 35
# Time elapsed (hh:mm:ss.ms) 0:01:01.428702
# 0.0006333417231493657
# Correct 3377
# Incorrect 1663
# Accuracy:  0.6700396825396825
# Time elapsed (hh:mm:ss.ms) 0:01:02.224138
# epoch num: 36
# Time elapsed (hh:mm:ss.ms) 0:01:03.005991
# 0.0007127212478935374
# Correct 3468
# Incorrect 1712
# Accuracy:  0.6694980694980694
# Time elapsed (hh:mm:ss.ms) 0:01:03.853219
# epoch num: 37
# Time elapsed (hh:mm:ss.ms) 0:01:04.638291
# 0.0007020261900509947
# Correct 3558
# Incorrect 1762
# Accuracy:  0.6687969924812031
# Time elapsed (hh:mm:ss.ms) 0:01:05.542154
# epoch num: 38
# Time elapsed (hh:mm:ss.ms) 0:01:06.295985
# 0.0005790580275180789
# Correct 3653
# Incorrect 1807
# Accuracy:  0.669047619047619
# Time elapsed (hh:mm:ss.ms) 0:01:07.130280
# epoch num: 39
# Time elapsed (hh:mm:ss.ms) 0:01:07.916587
# 0.0006403079897218422
# Correct 3761
# Incorrect 1839
# Accuracy:  0.6716071428571428
# Time elapsed (hh:mm:ss.ms) 0:01:08.798808
# epoch num: 40
# Time elapsed (hh:mm:ss.ms) 0:01:09.575140
# 0.0007316497097844662
# Correct 3853
# Incorrect 1887
# Accuracy:  0.6712543554006969
# Time elapsed (hh:mm:ss.ms) 0:01:10.410833
# epoch num: 41
# Time elapsed (hh:mm:ss.ms) 0:01:11.165585
# 0.0006802610369914659
# Correct 3956
# Incorrect 1924
# Accuracy:  0.6727891156462585
# Time elapsed (hh:mm:ss.ms) 0:01:12.086407
# epoch num: 42
# Time elapsed (hh:mm:ss.ms) 0:01:12.858663
# 0.0006009757605259296
# Correct 4057
# Incorrect 1963
# Accuracy:  0.6739202657807309
# Time elapsed (hh:mm:ss.ms) 0:01:13.721178
# epoch num: 43
# Time elapsed (hh:mm:ss.ms) 0:01:14.462942
# 0.0005933340439630289
# Correct 4157
# Incorrect 2003
# Accuracy:  0.6748376623376623
# Time elapsed (hh:mm:ss.ms) 0:01:15.280429
# epoch num: 44
# Time elapsed (hh:mm:ss.ms) 0:01:16.053460
# 0.0006098518186439236
# Correct 4258
# Incorrect 2042
# Accuracy:  0.6758730158730158
# Time elapsed (hh:mm:ss.ms) 0:01:16.929434
# epoch num: 45
# Time elapsed (hh:mm:ss.ms) 0:01:17.750551
# 0.0006562345538490503
# Correct 4367
# Incorrect 2073
# Accuracy:  0.6781055900621118
# Time elapsed (hh:mm:ss.ms) 0:01:18.605839
# epoch num: 46
# Time elapsed (hh:mm:ss.ms) 0:01:19.524752
# 0.00057600031582828
# Correct 4467
# Incorrect 2113
# Accuracy:  0.6788753799392098
# Time elapsed (hh:mm:ss.ms) 0:01:20.343808
# epoch num: 47
# Time elapsed (hh:mm:ss.ms) 0:01:21.270892
# 0.00048578831119487756
# Correct 4564
# Incorrect 2156
# Accuracy:  0.6791666666666667
# Time elapsed (hh:mm:ss.ms) 0:01:22.065796
# epoch num: 48
# Time elapsed (hh:mm:ss.ms) 0:01:22.862644
# 0.0005652018900000892
# Correct 4658
# Incorrect 2202
# Accuracy:  0.6790087463556851
# Time elapsed (hh:mm:ss.ms) 0:01:23.696191
# epoch num: 49
# Time elapsed (hh:mm:ss.ms) 0:01:24.481033
# 0.000530214765017451
# Correct 4767
# Incorrect 2233
# Accuracy:  0.681
# Time elapsed (hh:mm:ss.ms) 0:01:25.289247
# epoch num: 50
# Time elapsed (hh:mm:ss.ms) 0:01:26.061965
# 0.0006146000294418602
# Correct 4869
# Incorrect 2271
# Accuracy:  0.6819327731092437
# Time elapsed (hh:mm:ss.ms) 0:01:26.903844
# epoch num: 51
# Time elapsed (hh:mm:ss.ms) 0:01:27.659915
# 0.0005007344866567515
# Correct 4971
# Incorrect 2309
# Accuracy:  0.6828296703296703
# Time elapsed (hh:mm:ss.ms) 0:01:28.524455
# epoch num: 52
# Time elapsed (hh:mm:ss.ms) 0:01:29.311890
# 0.0005020100879075549
# Correct 5077
# Incorrect 2343
# Accuracy:  0.6842318059299192
# Time elapsed (hh:mm:ss.ms) 0:01:30.184918
# epoch num: 53
# Time elapsed (hh:mm:ss.ms) 0:01:30.991412
# 0.0005098332206828119
# Correct 5186
# Incorrect 2374
# Accuracy:  0.685978835978836
# Time elapsed (hh:mm:ss.ms) 0:01:31.849177
# epoch num: 54
# Time elapsed (hh:mm:ss.ms) 0:01:32.629491
# 0.00043393598552962377
# Correct 5291
# Incorrect 2409
# Accuracy:  0.6871428571428572
# Time elapsed (hh:mm:ss.ms) 0:01:33.448684
# epoch num: 55
# Time elapsed (hh:mm:ss.ms) 0:01:34.230274
# 0.00046045554766229764
# Correct 5389
# Incorrect 2451
# Accuracy:  0.6873724489795918
# Time elapsed (hh:mm:ss.ms) 0:01:35.090806
# epoch num: 56
# Time elapsed (hh:mm:ss.ms) 0:01:35.910866
# 0.0005378904746605249
# Correct 5504
# Incorrect 2476
# Accuracy:  0.6897243107769424
# Time elapsed (hh:mm:ss.ms) 0:01:36.819137
# epoch num: 57
# Time elapsed (hh:mm:ss.ms) 0:01:37.601738
# 0.0004765650791289035
# Correct 5601
# Incorrect 2519
# Accuracy:  0.6897783251231527
# Time elapsed (hh:mm:ss.ms) 0:01:38.440289
# epoch num: 58
# Time elapsed (hh:mm:ss.ms) 0:01:39.232719
# 0.0004238772961652264
# Correct 5702
# Incorrect 2558
# Accuracy:  0.6903147699757869
# Time elapsed (hh:mm:ss.ms) 0:01:40.030226
# epoch num: 59
# Time elapsed (hh:mm:ss.ms) 0:01:40.804566
# 0.0004473015595134458
# Correct 5812
# Incorrect 2588
# Accuracy:  0.6919047619047619
# Time elapsed (hh:mm:ss.ms) 0:01:41.645146
# epoch num: 60
# Time elapsed (hh:mm:ss.ms) 0:01:42.406754
# 0.0004379446089964861
# Correct 5914
# Incorrect 2626
# Accuracy:  0.6925058548009367
# Time elapsed (hh:mm:ss.ms) 0:01:43.271035
# epoch num: 61
# Time elapsed (hh:mm:ss.ms) 0:01:44.277542
# 0.00047577615780166433
# Correct 6012
# Incorrect 2668
# Accuracy:  0.6926267281105991
# Time elapsed (hh:mm:ss.ms) 0:01:45.097688
# epoch num: 62
# Time elapsed (hh:mm:ss.ms) 0:01:46.056737
# 0.0005184509290439221
# Correct 6110
# Incorrect 2710
# Accuracy:  0.6927437641723356
# Time elapsed (hh:mm:ss.ms) 0:01:46.887339
# epoch num: 63
# Time elapsed (hh:mm:ss.ms) 0:01:47.655033
# 0.0004604039641061887
# Correct 6201
# Incorrect 2759
# Accuracy:  0.6920758928571429
# Time elapsed (hh:mm:ss.ms) 0:01:48.585337
# epoch num: 64
# Time elapsed (hh:mm:ss.ms) 0:01:49.478513
# 0.0004279188296535798
# Correct 6301
# Incorrect 2799
# Accuracy:  0.6924175824175824
# Time elapsed (hh:mm:ss.ms) 0:01:50.350281
# epoch num: 65
# Time elapsed (hh:mm:ss.ms) 0:01:51.210379
# 0.0004978169098093703
# Correct 6397
# Incorrect 2843
# Accuracy:  0.6923160173160173
# Time elapsed (hh:mm:ss.ms) 0:01:52.060969
# epoch num: 66
# Time elapsed (hh:mm:ss.ms) 0:01:52.900412
# 0.0005121695847747424
# Correct 6500
# Incorrect 2880
# Accuracy:  0.6929637526652452
# Time elapsed (hh:mm:ss.ms) 0:01:53.732358
# epoch num: 67
# Time elapsed (hh:mm:ss.ms) 0:01:54.521926
# 0.00043664868346416437
# Correct 6594
# Incorrect 2926
# Accuracy:  0.6926470588235294
# Time elapsed (hh:mm:ss.ms) 0:01:55.376205
# epoch num: 68
# Time elapsed (hh:mm:ss.ms) 0:01:56.193271
# 0.0003256922917134266
# Correct 6711
# Incorrect 2949
# Accuracy:  0.69472049689441
# Time elapsed (hh:mm:ss.ms) 0:01:57.046754
# epoch num: 69
# Time elapsed (hh:mm:ss.ms) 0:01:57.913151
# 0.00045608572289727395
# Correct 6803
# Incorrect 2997
# Accuracy:  0.6941836734693878
# Time elapsed (hh:mm:ss.ms) 0:01:58.776994
# epoch num: 70
# Time elapsed (hh:mm:ss.ms) 0:01:59.557970
# 0.0005266582920922706
# Correct 6904
# Incorrect 3036
# Accuracy:  0.6945674044265594
# Time elapsed (hh:mm:ss.ms) 0:02:00.407735
# epoch num: 71
# Time elapsed (hh:mm:ss.ms) 0:02:01.181347
# 0.0004085294710337466
# Correct 7006
# Incorrect 3074
# Accuracy:  0.6950396825396825
# Time elapsed (hh:mm:ss.ms) 0:02:02.063873
# epoch num: 72
# Time elapsed (hh:mm:ss.ms) 0:02:02.956980
# 0.0004993288332590959
# Correct 7107
# Incorrect 3113
# Accuracy:  0.6954011741682975
# Time elapsed (hh:mm:ss.ms) 0:02:03.831078
# epoch num: 73
# Time elapsed (hh:mm:ss.ms) 0:02:04.625001
# 0.0004913969110902273
# Correct 7206
# Incorrect 3154
# Accuracy:  0.6955598455598455
# Time elapsed (hh:mm:ss.ms) 0:02:05.431019
# epoch num: 74
# Time elapsed (hh:mm:ss.ms) 0:02:06.193742
# 0.0004429267409242527
# Correct 7304
# Incorrect 3196
# Accuracy:  0.6956190476190476
# Time elapsed (hh:mm:ss.ms) 0:02:07.092566
# epoch num: 75
# Time elapsed (hh:mm:ss.ms) 0:02:07.971775
# 0.0003751860887791629
# Correct 7424
# Incorrect 3216
# Accuracy:  0.6977443609022557
# Time elapsed (hh:mm:ss.ms) 0:02:08.782852
# epoch num: 76
# Time elapsed (hh:mm:ss.ms) 0:02:09.557862
# 0.0003018266693158101
# Correct 7534
# Incorrect 3246
# Accuracy:  0.698886827458256
# Time elapsed (hh:mm:ss.ms) 0:02:10.495384
# epoch num: 77
# Time elapsed (hh:mm:ss.ms) 0:02:11.493422
# 0.00035549634479647475
# Correct 7641
# Incorrect 3279
# Accuracy:  0.6997252747252747
# Time elapsed (hh:mm:ss.ms) 0:02:12.473046
# epoch num: 78
# Time elapsed (hh:mm:ss.ms) 0:02:13.260779
# 0.00038479455656690865
# Correct 7750
# Incorrect 3310
# Accuracy:  0.7007233273056058
# Time elapsed (hh:mm:ss.ms) 0:02:14.117349
# epoch num: 79
# Time elapsed (hh:mm:ss.ms) 0:02:14.971105
# 0.0003406719356961382
# Correct 7864
# Incorrect 3336
# Accuracy:  0.7021428571428572
# Time elapsed (hh:mm:ss.ms) 0:02:15.897606
# epoch num: 80
# Time elapsed (hh:mm:ss.ms) 0:02:16.750671
# 0.00032561908471951924
# Correct 7959
# Incorrect 3381
# Accuracy:  0.7018518518518518
# Time elapsed (hh:mm:ss.ms) 0:02:17.609542
# epoch num: 81
# Time elapsed (hh:mm:ss.ms) 0:02:18.543737
# 0.0003262237135849381
# Correct 8067
# Incorrect 3413
# Accuracy:  0.7027003484320558
# Time elapsed (hh:mm:ss.ms) 0:02:19.437732
# epoch num: 82
# Time elapsed (hh:mm:ss.ms) 0:02:20.310672
# 0.00032561089801870334
# Correct 8181
# Incorrect 3439
# Accuracy:  0.7040447504302926
# Time elapsed (hh:mm:ss.ms) 0:02:21.144923
# epoch num: 83
# Time elapsed (hh:mm:ss.ms) 0:02:21.957096
# 0.00031648204680104935
# Correct 8281
# Incorrect 3479
# Accuracy:  0.7041666666666667
# Time elapsed (hh:mm:ss.ms) 0:02:22.818661
# epoch num: 84
# Time elapsed (hh:mm:ss.ms) 0:02:23.599841
# 0.0003110649459858485
# Correct 8390
# Incorrect 3510
# Accuracy:  0.7050420168067227
# Time elapsed (hh:mm:ss.ms) 0:02:24.524143
# epoch num: 85
# Time elapsed (hh:mm:ss.ms) 0:02:25.345998
# 0.00029507326387270854
# Correct 8495
# Incorrect 3545
# Accuracy:  0.7055647840531561
# Time elapsed (hh:mm:ss.ms) 0:02:26.223452
# epoch num: 86
# Time elapsed (hh:mm:ss.ms) 0:02:27.158535
# 0.0002612044440370001
# Correct 8602
# Incorrect 3578
# Accuracy:  0.7062397372742201
# Time elapsed (hh:mm:ss.ms) 0:02:28.069346
# epoch num: 87
# Time elapsed (hh:mm:ss.ms) 0:02:28.894767
# 0.00026441137068463065
# Correct 8714
# Incorrect 3606
# Accuracy:  0.7073051948051948
# Time elapsed (hh:mm:ss.ms) 0:02:29.783376
# epoch num: 88
# Time elapsed (hh:mm:ss.ms) 0:02:30.552761
# 0.00025996667689194943
# Correct 8825
# Incorrect 3635
# Accuracy:  0.7082664526484751
# Time elapsed (hh:mm:ss.ms) 0:02:31.397972
# epoch num: 89
# Time elapsed (hh:mm:ss.ms) 0:02:32.179419
# 0.00038158939671270625
# Correct 8935
# Incorrect 3665
# Accuracy:  0.7091269841269842
# Time elapsed (hh:mm:ss.ms) 0:02:33.022102
# epoch num: 90
# Time elapsed (hh:mm:ss.ms) 0:02:33.855118
# 0.0004531437509200152
# Correct 9020
# Incorrect 3720
# Accuracy:  0.7080062794348508
# Time elapsed (hh:mm:ss.ms) 0:02:34.764360
# epoch num: 91
# Time elapsed (hh:mm:ss.ms) 0:02:35.699281
# 0.0005015583435771445
# Correct 9117
# Incorrect 3763
# Accuracy:  0.7078416149068323
# Time elapsed (hh:mm:ss.ms) 0:02:36.597212
# epoch num: 92
# Time elapsed (hh:mm:ss.ms) 0:02:37.469877
# 0.0005171920243630661
# Correct 9204
# Incorrect 3816
# Accuracy:  0.7069124423963133
# Time elapsed (hh:mm:ss.ms) 0:02:38.352488
# epoch num: 93
# Time elapsed (hh:mm:ss.ms) 0:02:39.331391
# 0.0003611764721374396
# Correct 9317
# Incorrect 3843
# Accuracy:  0.7079787234042553
# Time elapsed (hh:mm:ss.ms) 0:02:40.235318
# epoch num: 94
# Time elapsed (hh:mm:ss.ms) 0:02:41.026656
# 0.00026319319260559255
# Correct 9427
# Incorrect 3873
# Accuracy:  0.708796992481203
# Time elapsed (hh:mm:ss.ms) 0:02:41.935064
# epoch num: 95
# Time elapsed (hh:mm:ss.ms) 0:02:42.756223
# 0.00024330234051193889
# Correct 9549
# Incorrect 3891
# Accuracy:  0.7104910714285714
# Time elapsed (hh:mm:ss.ms) 0:02:43.641244
# epoch num: 96
# Time elapsed (hh:mm:ss.ms) 0:02:44.638233
# 0.00037401791242574225
# Correct 9656
# Incorrect 3924
# Accuracy:  0.7110456553755523
# Time elapsed (hh:mm:ss.ms) 0:02:45.761192
# epoch num: 97
# Time elapsed (hh:mm:ss.ms) 0:02:46.633961
# 0.00023277656046995175
# Correct 9760
# Incorrect 3960
# Accuracy:  0.7113702623906706
# Time elapsed (hh:mm:ss.ms) 0:02:47.528537
# epoch num: 98
# Time elapsed (hh:mm:ss.ms) 0:02:48.319483
# 0.00023868269600624135
# Correct 9868
# Incorrect 3992
# Accuracy:  0.7119769119769119
# Time elapsed (hh:mm:ss.ms) 0:02:49.172443
# epoch num: 99
# Time elapsed (hh:mm:ss.ms) 0:02:49.955833
# 0.00028920596163669373
# Correct 9987
# Incorrect 4013
# Accuracy:  0.7133571428571429
# Time elapsed (hh:mm:ss.ms) 0:02:50.859486
# epoch num: 100
# Time elapsed (hh:mm:ss.ms) 0:02:51.806562
# 0.00020141268260908632
# Correct 10100
# Incorrect 4040
# Accuracy:  0.7142857142857143
# Time elapsed (hh:mm:ss.ms) 0:02:52.664249
# epoch num: 101
# Time elapsed (hh:mm:ss.ms) 0:02:53.418028
# 0.00023850115072151596
# Correct 10213
# Incorrect 4067
# Accuracy:  0.7151960784313726
# Time elapsed (hh:mm:ss.ms) 0:02:54.250527
# epoch num: 102
# Time elapsed (hh:mm:ss.ms) 0:02:55.312568
# 0.00019692640547651593
# Correct 10330
# Incorrect 4090
# Accuracy:  0.7163661581137309
# Time elapsed (hh:mm:ss.ms) 0:02:56.234857
# epoch num: 103
# Time elapsed (hh:mm:ss.ms) 0:02:57.056151
# 0.00019975884593179477
# Correct 10452
# Incorrect 4108
# Accuracy:  0.7178571428571429
# Time elapsed (hh:mm:ss.ms) 0:02:57.949476
# epoch num: 104
# Time elapsed (hh:mm:ss.ms) 0:02:58.757526
# 0.00021529206809828996
# Correct 10565
# Incorrect 4135
# Accuracy:  0.7187074829931973
# Time elapsed (hh:mm:ss.ms) 0:02:59.579505
# epoch num: 105
# Time elapsed (hh:mm:ss.ms) 0:03:00.396776
# 0.00035187830828657056
# Correct 10670
# Incorrect 4170
# Accuracy:  0.7190026954177897
# Time elapsed (hh:mm:ss.ms) 0:03:01.275024
# epoch num: 106
# Time elapsed (hh:mm:ss.ms) 0:03:02.236445
# 0.00029233406938418616
# Correct 10785
# Incorrect 4195
# Accuracy:  0.7199599465954606
# Time elapsed (hh:mm:ss.ms) 0:03:03.071411
# epoch num: 107
# Time elapsed (hh:mm:ss.ms) 0:03:03.855320
# 0.00019722043611084634
# Correct 10904
# Incorrect 4216
# Accuracy:  0.7211640211640211
# Time elapsed (hh:mm:ss.ms) 0:03:04.647169
# epoch num: 108
# Time elapsed (hh:mm:ss.ms) 0:03:05.435681
# 0.0003410659793864377
# Correct 11021
# Incorrect 4239
# Accuracy:  0.7222149410222805
# Time elapsed (hh:mm:ss.ms) 0:03:06.241173
# epoch num: 109
# Time elapsed (hh:mm:ss.ms) 0:03:07.039405
# 0.000282859844309722
# Correct 11135
# Incorrect 4265
# Accuracy:  0.7230519480519481
# Time elapsed (hh:mm:ss.ms) 0:03:07.863766
# epoch num: 110
# Time elapsed (hh:mm:ss.ms) 0:03:08.670854
# 0.00032832855867802904
# Correct 11247
# Incorrect 4293
# Accuracy:  0.7237451737451738
# Time elapsed (hh:mm:ss.ms) 0:03:09.512815
# epoch num: 111
# Time elapsed (hh:mm:ss.ms) 0:03:10.310304
# 0.0002502478312503919
# Correct 11365
# Incorrect 4315
# Accuracy:  0.7248086734693877
# Time elapsed (hh:mm:ss.ms) 0:03:11.238564
# epoch num: 112
# Time elapsed (hh:mm:ss.ms) 0:03:12.038102
# 0.00028177003646228256
# Correct 11477
# Incorrect 4343
# Accuracy:  0.7254740834386852
# Time elapsed (hh:mm:ss.ms) 0:03:12.915465
# epoch num: 113
# Time elapsed (hh:mm:ss.ms) 0:03:13.693046
# 0.0001741955704105296
# Correct 11594
# Incorrect 4366
# Accuracy:  0.7264411027568922
# Time elapsed (hh:mm:ss.ms) 0:03:14.518414
# epoch num: 114
# Time elapsed (hh:mm:ss.ms) 0:03:15.315770
# 0.00018941198286619488
# Correct 11718
# Incorrect 4382
# Accuracy:  0.7278260869565217
# Time elapsed (hh:mm:ss.ms) 0:03:16.111999
# epoch num: 115
# Time elapsed (hh:mm:ss.ms) 0:03:16.905670
# 0.00028869997767301704
# Correct 11834
# Incorrect 4406
# Accuracy:  0.7286945812807881
# Time elapsed (hh:mm:ss.ms) 0:03:17.742098
# epoch num: 116
# Time elapsed (hh:mm:ss.ms) 0:03:18.511622
# 0.0004301538021554301
# Correct 11932
# Incorrect 4448
# Accuracy:  0.7284493284493284
# Time elapsed (hh:mm:ss.ms) 0:03:19.425509
# epoch num: 117
# Time elapsed (hh:mm:ss.ms) 0:03:20.294715
# 0.00023210484081517547
# Correct 12049
# Incorrect 4471
# Accuracy:  0.7293583535108958
# Time elapsed (hh:mm:ss.ms) 0:03:21.149240
# epoch num: 118
# Time elapsed (hh:mm:ss.ms) 0:03:21.971381
# 0.00024059359665823754
# Correct 12172
# Incorrect 4488
# Accuracy:  0.7306122448979592
# Time elapsed (hh:mm:ss.ms) 0:03:22.875066
# epoch num: 119
# Time elapsed (hh:mm:ss.ms) 0:03:23.739661
# 0.00022128102264895033
# Correct 12295
# Incorrect 4505
# Accuracy:  0.731845238095238
# Time elapsed (hh:mm:ss.ms) 0:03:24.613888
# epoch num: 120
# Time elapsed (hh:mm:ss.ms) 0:03:25.413913
# 0.00019330183664957682
# Correct 12417
# Incorrect 4523
# Accuracy:  0.7329988193624557
# Time elapsed (hh:mm:ss.ms) 0:03:26.374295
# epoch num: 121
# Time elapsed (hh:mm:ss.ms) 0:03:27.190929
# 0.0001771940477519373
# Correct 12540
# Incorrect 4540
# Accuracy:  0.734192037470726
# Time elapsed (hh:mm:ss.ms) 0:03:28.081350
# epoch num: 122
# Time elapsed (hh:mm:ss.ms) 0:03:28.960771
# 0.0001922370428116738
# Correct 12651
# Incorrect 4569
# Accuracy:  0.7346689895470383
# Time elapsed (hh:mm:ss.ms) 0:03:29.822384
# epoch num: 123
# Time elapsed (hh:mm:ss.ms) 0:03:30.645327
# 0.0002972901802537904
# Correct 12768
# Incorrect 4592
# Accuracy:  0.7354838709677419
# Time elapsed (hh:mm:ss.ms) 0:03:31.523920
# epoch num: 124
# Time elapsed (hh:mm:ss.ms) 0:03:32.332544
# 0.000246885908647376
# Correct 12886
# Incorrect 4614
# Accuracy:  0.7363428571428572
# Time elapsed (hh:mm:ss.ms) 0:03:33.256950
# epoch num: 125
# Time elapsed (hh:mm:ss.ms) 0:03:34.175246
# 0.00024922112103224476
# Correct 13003
# Incorrect 4637
# Accuracy:  0.7371315192743764
# Time elapsed (hh:mm:ss.ms) 0:03:35.011523
# epoch num: 126
# Time elapsed (hh:mm:ss.ms) 0:03:35.805778
# 0.00019235286846999844
# Correct 13131
# Incorrect 4649
# Accuracy:  0.7385264341957255
# Time elapsed (hh:mm:ss.ms) 0:03:36.637111
# epoch num: 127
# Time elapsed (hh:mm:ss.ms) 0:03:37.433585
# 0.0002742012411073407
# Correct 13254
# Incorrect 4666
# Accuracy:  0.7396205357142858
# Time elapsed (hh:mm:ss.ms) 0:03:38.278187
# epoch num: 128
# Time elapsed (hh:mm:ss.ms) 0:03:39.079260
# 0.00016013181582299397
# Correct 13379
# Incorrect 4681
# Accuracy:  0.7408084163898118
# Time elapsed (hh:mm:ss.ms) 0:03:39.906358
# epoch num: 129
# Time elapsed (hh:mm:ss.ms) 0:03:40.899043
# 0.0002019782026412394
# Correct 13505
# Incorrect 4695
# Accuracy:  0.7420329670329671
# Time elapsed (hh:mm:ss.ms) 0:03:41.739084
# epoch num: 130
# Time elapsed (hh:mm:ss.ms) 0:03:42.508689
# 0.0002583971891643566
# Correct 13625
# Incorrect 4715
# Accuracy:  0.7429116684841875
# Time elapsed (hh:mm:ss.ms) 0:03:43.340117
# epoch num: 131
# Time elapsed (hh:mm:ss.ms) 0:03:44.356017
# 0.0002660309566459893
# Correct 13726
# Incorrect 4754
# Accuracy:  0.7427489177489177
# Time elapsed (hh:mm:ss.ms) 0:03:45.151203
# epoch num: 132
# Time elapsed (hh:mm:ss.ms) 0:03:45.947105
# 0.00024819214314910205
# Correct 13849
# Incorrect 4771
# Accuracy:  0.7437701396348013
# Time elapsed (hh:mm:ss.ms) 0:03:46.792330
# epoch num: 133
# Time elapsed (hh:mm:ss.ms) 0:03:47.615847
# 0.000243583748679753
# Correct 13973
# Incorrect 4787
# Accuracy:  0.7448294243070362
# Time elapsed (hh:mm:ss.ms) 0:03:48.461399
# epoch num: 134
# Time elapsed (hh:mm:ss.ms) 0:03:49.214057
# 0.00022058963326472317
# Correct 14092
# Incorrect 4808
# Accuracy:  0.7456084656084656
# Time elapsed (hh:mm:ss.ms) 0:03:50.042787
# epoch num: 135
# Time elapsed (hh:mm:ss.ms) 0:03:50.844123
# 0.0002170707864241963
# Correct 14211
# Incorrect 4829
# Accuracy:  0.7463760504201681
# Time elapsed (hh:mm:ss.ms) 0:03:51.718097
# epoch num: 136
# Time elapsed (hh:mm:ss.ms) 0:03:52.482779
# 0.0003637151327712142
# Correct 14330
# Incorrect 4850
# Accuracy:  0.7471324296141815
# Time elapsed (hh:mm:ss.ms) 0:03:53.320510
# epoch num: 137
# Time elapsed (hh:mm:ss.ms) 0:03:54.127614
# 0.00033005466323347826
# Correct 14442
# Incorrect 4878
# Accuracy:  0.7475155279503105
# Time elapsed (hh:mm:ss.ms) 0:03:55.001075
# epoch num: 138
# Time elapsed (hh:mm:ss.ms) 0:03:55.923809
# 0.00020116720105601264
# Correct 14566
# Incorrect 4894
# Accuracy:  0.7485097636176773
# Time elapsed (hh:mm:ss.ms) 0:03:56.748235
# epoch num: 139
# Time elapsed (hh:mm:ss.ms) 0:03:57.599195
# 0.00017587459099529837
# Correct 14692
# Incorrect 4908
# Accuracy:  0.7495918367346939
# Time elapsed (hh:mm:ss.ms) 0:03:58.459355
# epoch num: 140
# Time elapsed (hh:mm:ss.ms) 0:03:59.252210
# 0.00014794501039800764
# Correct 14815
# Incorrect 4925
# Accuracy:  0.7505065856129686
# Time elapsed (hh:mm:ss.ms) 0:04:00.089466
# epoch num: 141
# Time elapsed (hh:mm:ss.ms) 0:04:00.856276
# 0.00021065514986091908
# Correct 14936
# Incorrect 4944
# Accuracy:  0.751307847082495
# Time elapsed (hh:mm:ss.ms) 0:04:01.683189
# epoch num: 142
# Time elapsed (hh:mm:ss.ms) 0:04:02.449490
# 0.00018520637067091566
# Correct 15045
# Incorrect 4975
# Accuracy:  0.7514985014985015
# Time elapsed (hh:mm:ss.ms) 0:04:03.268848
# epoch num: 143
# Time elapsed (hh:mm:ss.ms) 0:04:04.111089
# 0.00021229666806886737
# Correct 15163
# Incorrect 4997
# Accuracy:  0.7521329365079366
# Time elapsed (hh:mm:ss.ms) 0:04:04.932557
# epoch num: 144
# Time elapsed (hh:mm:ss.ms) 0:04:05.751332
# 0.00022780500693546618
# Correct 15292
# Incorrect 5008
# Accuracy:  0.7533004926108374
# Time elapsed (hh:mm:ss.ms) 0:04:06.737850
# epoch num: 145
# Time elapsed (hh:mm:ss.ms) 0:04:07.542699
# 0.00032269153880606655
# Correct 15399
# Incorrect 5041
# Accuracy:  0.7533757338551859
# Time elapsed (hh:mm:ss.ms) 0:04:08.432283
# epoch num: 146
# Time elapsed (hh:mm:ss.ms) 0:04:09.211816
# 0.00030599311247446286
# Correct 15502
# Incorrect 5078
# Accuracy:  0.7532555879494655
# Time elapsed (hh:mm:ss.ms) 0:04:10.113487
# epoch num: 147
# Time elapsed (hh:mm:ss.ms) 0:04:10.919551
# 0.0001966454936896783
# Correct 15630
# Incorrect 5090
# Accuracy:  0.7543436293436293
# Time elapsed (hh:mm:ss.ms) 0:04:11.828070
# epoch num: 148
# Time elapsed (hh:mm:ss.ms) 0:04:12.600736
# 0.00020898170287265237
# Correct 15751
# Incorrect 5109
# Accuracy:  0.7550814956855225
# Time elapsed (hh:mm:ss.ms) 0:04:13.457661
# epoch num: 149
# Time elapsed (hh:mm:ss.ms) 0:04:14.322819
# 0.0002457916236587617
# Correct 15871
# Incorrect 5129
# Accuracy:  0.7557619047619047
# Time elapsed (hh:mm:ss.ms) 0:04:15.141609
# epoch num: 150
# Time elapsed (hh:mm:ss.ms) 0:04:15.909901
# 0.00022001904798737653
# Correct 15998
# Incorrect 5142
# Accuracy:  0.7567644276253548
# Time elapsed (hh:mm:ss.ms) 0:04:16.788320
# epoch num: 151
# Time elapsed (hh:mm:ss.ms) 0:04:17.598574
# 0.00018647203231540965
# Correct 16130
# Incorrect 5150
# Accuracy:  0.7579887218045113
# Time elapsed (hh:mm:ss.ms) 0:04:18.491985
# epoch num: 152
# Time elapsed (hh:mm:ss.ms) 0:04:19.323152
# 0.00017612885529061538
# Correct 16252
# Incorrect 5168
# Accuracy:  0.7587301587301587
# Time elapsed (hh:mm:ss.ms) 0:04:20.201682
# epoch num: 153
# Time elapsed (hh:mm:ss.ms) 0:04:21.144305
# 0.00021116745364185168
# Correct 16373
# Incorrect 5187
# Accuracy:  0.7594155844155844
# Time elapsed (hh:mm:ss.ms) 0:04:22.015073
# epoch num: 154
# Time elapsed (hh:mm:ss.ms) 0:04:22.926366
# 0.0001659272062729054
# Correct 16500
# Incorrect 5200
# Accuracy:  0.7603686635944701
# Time elapsed (hh:mm:ss.ms) 0:04:23.803252
# epoch num: 155
# Time elapsed (hh:mm:ss.ms) 0:04:24.744437
# 0.00022716724251991552
# Correct 16621
# Incorrect 5219
# Accuracy:  0.7610347985347985
# Time elapsed (hh:mm:ss.ms) 0:04:25.653235
# epoch num: 156
# Time elapsed (hh:mm:ss.ms) 0:04:26.551207
# 0.0002569658270934974
# Correct 16737
# Incorrect 5243
# Accuracy:  0.7614649681528662
# Time elapsed (hh:mm:ss.ms) 0:04:27.445016
# epoch num: 157
# Time elapsed (hh:mm:ss.ms) 0:04:28.227419
# 0.00016926798819687588
# Correct 16864
# Incorrect 5256
# Accuracy:  0.7623869801084991
# Time elapsed (hh:mm:ss.ms) 0:04:29.090654
# epoch num: 158
# Time elapsed (hh:mm:ss.ms) 0:04:29.879794
# 0.0001343012660688277
# Correct 16990
# Incorrect 5270
# Accuracy:  0.7632524707996406
# Time elapsed (hh:mm:ss.ms) 0:04:30.733059
# epoch num: 159
# Time elapsed (hh:mm:ss.ms) 0:04:31.500463
# 0.00018648560865815864
# Correct 17102
# Incorrect 5298
# Accuracy:  0.7634821428571429
# Time elapsed (hh:mm:ss.ms) 0:04:32.394978
# epoch num: 160
# Time elapsed (hh:mm:ss.ms) 0:04:33.234258
# 0.00015987560252128313
# Correct 17229
# Incorrect 5311
# Accuracy:  0.764374445430346
# Time elapsed (hh:mm:ss.ms) 0:04:34.100860
# epoch num: 161
# Time elapsed (hh:mm:ss.ms) 0:04:34.984170
# 0.0002660615235869188
# Correct 17356
# Incorrect 5324
# Accuracy:  0.7652557319223986
# Time elapsed (hh:mm:ss.ms) 0:04:35.828787
# epoch num: 162
# Time elapsed (hh:mm:ss.ms) 0:04:36.598597
# 0.0001844926572033986
# Correct 17485
# Incorrect 5335
# Accuracy:  0.766213847502191
# Time elapsed (hh:mm:ss.ms) 0:04:37.460740
# epoch num: 163
# Time elapsed (hh:mm:ss.ms) 0:04:38.292390
# 0.00023139872445092805
# Correct 17614
# Incorrect 5346
# Accuracy:  0.7671602787456446
# Time elapsed (hh:mm:ss.ms) 0:04:39.163777
# epoch num: 164
# Time elapsed (hh:mm:ss.ms) 0:04:39.982601
# 0.00020183087014264743
# Correct 17737
# Incorrect 5363
# Accuracy:  0.7678354978354979
# Time elapsed (hh:mm:ss.ms) 0:04:40.811569
# epoch num: 165
# Time elapsed (hh:mm:ss.ms) 0:04:41.648132
# 0.00024310170162108636
# Correct 17858
# Incorrect 5382
# Accuracy:  0.7684165232358003
# Time elapsed (hh:mm:ss.ms) 0:04:42.517277
# epoch num: 166
# Time elapsed (hh:mm:ss.ms) 0:04:43.303008
# 0.00016175067373171175
# Correct 17989
# Incorrect 5391
# Accuracy:  0.7694183062446536
# Time elapsed (hh:mm:ss.ms) 0:04:44.174329
# epoch num: 167
# Time elapsed (hh:mm:ss.ms) 0:04:45.024394
# 0.00023700795272943876
# Correct 18116
# Incorrect 5404
# Accuracy:  0.7702380952380953
# Time elapsed (hh:mm:ss.ms) 0:04:45.862108
# epoch num: 168
# Time elapsed (hh:mm:ss.ms) 0:04:46.775269
# 0.00023867314375298004
# Correct 18236
# Incorrect 5424
# Accuracy:  0.7707523245984784
# Time elapsed (hh:mm:ss.ms) 0:04:47.602742
# epoch num: 169
# Time elapsed (hh:mm:ss.ms) 0:04:48.403535
# 0.00020931016048279593
# Correct 18366
# Incorrect 5434
# Accuracy:  0.7716806722689076
# Time elapsed (hh:mm:ss.ms) 0:04:49.328291
# epoch num: 170
# Time elapsed (hh:mm:ss.ms) 0:04:50.187899
# 0.00028538919192017494
# Correct 18491
# Incorrect 5449
# Accuracy:  0.772389306599833
# Time elapsed (hh:mm:ss.ms) 0:04:51.073564
# epoch num: 171
# Time elapsed (hh:mm:ss.ms) 0:04:51.844816
# 0.0002826591895645018
# Correct 18607
# Incorrect 5473
# Accuracy:  0.7727159468438538
# Time elapsed (hh:mm:ss.ms) 0:04:52.782145
# epoch num: 172
# Time elapsed (hh:mm:ss.ms) 0:04:53.560283
# 0.0001854117924375963
# Correct 18727
# Incorrect 5493
# Accuracy:  0.7732039636663914
# Time elapsed (hh:mm:ss.ms) 0:04:54.437983
# epoch num: 173
# Time elapsed (hh:mm:ss.ms) 0:04:55.235259
# 0.00019276841166423488
# Correct 18852
# Incorrect 5508
# Accuracy:  0.7738916256157635
# Time elapsed (hh:mm:ss.ms) 0:04:56.105447
# epoch num: 174
# Time elapsed (hh:mm:ss.ms) 0:04:56.947361
# 0.000100069810791752
# Correct 18987
# Incorrect 5513
# Accuracy:  0.7749795918367347
# Time elapsed (hh:mm:ss.ms) 0:04:57.783430
# epoch num: 175
# Time elapsed (hh:mm:ss.ms) 0:04:58.722591
# 0.0001624220237891524
# Correct 19120
# Incorrect 5520
# Accuracy:  0.775974025974026
# Time elapsed (hh:mm:ss.ms) 0:04:59.587357
# epoch num: 176
# Time elapsed (hh:mm:ss.ms) 0:05:00.397969
# 0.00025996056239948294
# Correct 19235
# Incorrect 5545
# Accuracy:  0.7762308313155771
# Time elapsed (hh:mm:ss.ms) 0:05:01.243149
# epoch num: 177
# Time elapsed (hh:mm:ss.ms) 0:05:02.064636
# 0.00013902095791641316
# Correct 19370
# Incorrect 5550
# Accuracy:  0.7772873194221509
# Time elapsed (hh:mm:ss.ms) 0:05:02.885766
# epoch num: 178
# Time elapsed (hh:mm:ss.ms) 0:05:03.724762
# 0.00021940740334307668
# Correct 19504
# Incorrect 5556
# Accuracy:  0.7782920989624901
# Time elapsed (hh:mm:ss.ms) 0:05:04.630056
# epoch num: 179
# Time elapsed (hh:mm:ss.ms) 0:05:05.557325
# 0.00016727727697109335
# Correct 19634
# Incorrect 5566
# Accuracy:  0.7791269841269841
# Time elapsed (hh:mm:ss.ms) 0:05:06.531279
# epoch num: 180
# Time elapsed (hh:mm:ss.ms) 0:05:07.463903
# 0.00016973910952460837
# Correct 19766
# Incorrect 5574
# Accuracy:  0.7800315706393054
# Time elapsed (hh:mm:ss.ms) 0:05:08.388633
# epoch num: 181
# Time elapsed (hh:mm:ss.ms) 0:05:09.150108
# 0.00017888403233475383
# Correct 19897
# Incorrect 5583
# Accuracy:  0.7808869701726845
# Time elapsed (hh:mm:ss.ms) 0:05:09.973014
# epoch num: 182
# Time elapsed (hh:mm:ss.ms) 0:05:10.958352
# 0.00015767124473141638
# Correct 20031
# Incorrect 5589
# Accuracy:  0.7818501170960187
# Time elapsed (hh:mm:ss.ms) 0:05:11.829132
# epoch num: 183
# Time elapsed (hh:mm:ss.ms) 0:05:12.649231
# 0.00017952014788620964
# Correct 20153
# Incorrect 5607
# Accuracy:  0.7823369565217392
# Time elapsed (hh:mm:ss.ms) 0:05:13.546744
# epoch num: 184
# Time elapsed (hh:mm:ss.ms) 0:05:14.499663
# 0.00023858784617074712
# Correct 20275
# Incorrect 5625
# Accuracy:  0.7828185328185329
# Time elapsed (hh:mm:ss.ms) 0:05:15.405393
# epoch num: 185
# Time elapsed (hh:mm:ss.ms) 0:05:16.325532
# 0.0001982967120786546
# Correct 20401
# Incorrect 5639
# Accuracy:  0.7834485407066052
# Time elapsed (hh:mm:ss.ms) 0:05:17.159347
# epoch num: 186
# Time elapsed (hh:mm:ss.ms) 0:05:17.945306
# 0.00016624309796784477
# Correct 20537
# Incorrect 5643
# Accuracy:  0.784453781512605
# Time elapsed (hh:mm:ss.ms) 0:05:18.778400
# epoch num: 187
# Time elapsed (hh:mm:ss.ms) 0:05:19.568033
# 0.00020978125247310606
# Correct 20665
# Incorrect 5655
# Accuracy:  0.7851443768996961
# Time elapsed (hh:mm:ss.ms) 0:05:20.411303
# epoch num: 188
# Time elapsed (hh:mm:ss.ms) 0:05:21.221940
# 0.00017329327224514194
# Correct 20797
# Incorrect 5663
# Accuracy:  0.785978835978836
# Time elapsed (hh:mm:ss.ms) 0:05:22.111925
# epoch num: 189
# Time elapsed (hh:mm:ss.ms) 0:05:22.910103
# 6.356309190790082e-05
# Correct 20936
# Incorrect 5664
# Accuracy:  0.7870676691729324
# Time elapsed (hh:mm:ss.ms) 0:05:23.734388
# epoch num: 190
# Time elapsed (hh:mm:ss.ms) 0:05:24.533998
# 0.00015472935599701427
# Correct 21064
# Incorrect 5676
# Accuracy:  0.78773373223635
# Time elapsed (hh:mm:ss.ms) 0:05:25.343420
# epoch num: 191
# Time elapsed (hh:mm:ss.ms) 0:05:26.181814
# 0.0001660137073275058
# Correct 21188
# Incorrect 5692
# Accuracy:  0.7882440476190476
# Time elapsed (hh:mm:ss.ms) 0:05:27.099030
# epoch num: 192
# Time elapsed (hh:mm:ss.ms) 0:05:27.874108
# 0.00010892447246816747
# Correct 21325
# Incorrect 5695
# Accuracy:  0.7892301998519615
# Time elapsed (hh:mm:ss.ms) 0:05:28.779601
# epoch num: 193
# Time elapsed (hh:mm:ss.ms) 0:05:29.711138
# 0.0002603670462203631
# Correct 21456
# Incorrect 5704
# Accuracy:  0.7899852724594992
# Time elapsed (hh:mm:ss.ms) 0:05:30.527751
# epoch num: 194
# Time elapsed (hh:mm:ss.ms) 0:05:31.309114
# 0.00035343616273280075
# Correct 21543
# Incorrect 5757
# Accuracy:  0.7891208791208791
# Time elapsed (hh:mm:ss.ms) 0:05:32.163257
# epoch num: 195
# Time elapsed (hh:mm:ss.ms) 0:05:32.937529
# 0.00028637121338227626
# Correct 21649
# Incorrect 5791
# Accuracy:  0.7889577259475219
# Time elapsed (hh:mm:ss.ms) 0:05:33.759386
# epoch num: 196
# Time elapsed (hh:mm:ss.ms) 0:05:34.550324
# 0.00015746772251469624
# Correct 21782
# Incorrect 5798
# Accuracy:  0.7897751994198695
# Time elapsed (hh:mm:ss.ms) 0:05:35.526279
# epoch num: 197
# Time elapsed (hh:mm:ss.ms) 0:05:36.338522
# 0.00016848813088156023
# Correct 21912
# Incorrect 5808
# Accuracy:  0.7904761904761904
# Time elapsed (hh:mm:ss.ms) 0:05:37.204365
# epoch num: 198
# Time elapsed (hh:mm:ss.ms) 0:05:37.999370
# 0.0001639211834396647
# Correct 22045
# Incorrect 5815
# Accuracy:  0.7912778176597272
# Time elapsed (hh:mm:ss.ms) 0:05:38.840688
# epoch num: 199
# Time elapsed (hh:mm:ss.ms) 0:05:39.637151
# 0.0001337777202106382
# Correct 22179
# Incorrect 5821
# Accuracy:  0.7921071428571429
# Time elapsed (hh:mm:ss.ms) 0:05:40.587579
